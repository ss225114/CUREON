# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
img_size = 180
batch_size = 32

# %%
data_train_path = 'data_split/train'
data_test_path = 'data_split/test'

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_size, img_size),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_size, img_size),
    batch_size=batch_size
)

class_names = train_ds.class_names
num_classes = len(class_names)
# Out:
# Found 1133 files belonging to 24 classes.
# Using 907 files for training.
# Found 1133 files belonging to 24 classes.
# Using 226 files for validation.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
base_model = tf.keras.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_shape=(img_size, img_size, 3)
)

base_model.trainable = False  # Freeze base

# %%
from tensorflow.keras import layers

model = tf.keras.Sequential([
    layers.Input(shape=(img_size, img_size, 3)),
    layers.Lambda(tf.keras.applications.efficientnet.preprocess_input),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# history = model.fit(
#     train_ds,
#     validation_data=val_ds,
#     epochs=
# )
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 45s 860ms/step - accuracy: 0.0364 - loss: 4.3866 - val_accuracy: 0.0442 - val_loss: 3.1608
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 32s 530ms/step - accuracy: 0.0534 - loss: 3.8854 - val_accuracy: 0.0708 - val_loss: 3.0269
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 585ms/step - accuracy: 0.0680 - loss: 3.6968 - val_accuracy: 0.1593 - val_loss: 2.8913
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.1396 - loss: 3.2894 - val_accuracy: 0.2124 - val_loss: 2.7671
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 730ms/step - accuracy: 0.1817 - loss: 3.0871 - val_accuracy: 0.2743 - val_loss: 2.6481
# Epoch 6/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 555ms/step - accuracy: 0.1715 - loss: 2.9579 - val_accuracy: 0.3009 - val_loss: 2.5339
# Epoch 7/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 651ms/step - accuracy: 0.2125 - loss: 2.7680 - val_accuracy: 0.3319 - val_loss: 2.4273
# Epoch 8/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 592ms/step - accuracy: 0.3227 - loss: 2.4191 - val_accuracy: 0.3584 - val_loss: 2.3260
# Epoch 9/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 519ms/step - accuracy: 0.3006 - loss: 2.3260 - val_accuracy: 0.3673 - val_loss: 2.2369
# Epoch 10/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 557ms/step - accuracy: 0.3411 - loss: 2.2600 - val_accuracy: 0.3805 - val_loss: 2.1642
# Epoch 11/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 655ms/step - accuracy: 0.3580 - loss: 2.1713 - val_accuracy: 0.3850 - val_loss: 2.0961
# Epoch 12/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 22s 747ms/step - accuracy: 0.3894 - loss: 2.0402 - val_accuracy: 0.3850 - val_loss: 2.0461
# Epoch 13/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 24s 810ms/step - accuracy: 0.4243 - loss: 1.9559 - val_accuracy: 0.3894 - val_loss: 2.0015
# Epoch 14/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 26s 907ms/step - accuracy: 0.3904 - loss: 1.9514 - val_accuracy: 0.3938 - val_loss: 1.9622
# Epoch 15/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 25s 842ms/step - accuracy: 0.4493 - loss: 1.8344 - val_accuracy: 0.4027 - val_loss: 1.9313
# Epoch 16/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 645ms/step - accuracy: 0.4502 - loss: 1.8163 - val_accuracy: 0.4115 - val_loss: 1.9017
# Epoch 17/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 23s 787ms/step - accuracy: 0.4747 - loss: 1.7343 - val_accuracy: 0.4292 - val_loss: 1.8802
# Epoch 18/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 622ms/step - accuracy: 0.5313 - loss: 1.5683 - val_accuracy: 0.4513 - val_loss: 1.8541
# Epoch 19/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 602ms/step - accuracy: 0.5208 - loss: 1.5999 - val_accuracy: 0.4602 - val_loss: 1.8320
# Epoch 20/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 657ms/step - accuracy: 0.5471 - loss: 1.5072 - val_accuracy: 0.4867 - val_loss: 1.8123
# Epoch 21/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 587ms/step - accuracy: 0.5321 - loss: 1.4968 - val_accuracy: 0.4912 - val_loss: 1.7937
# Epoch 22/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 528ms/step - accuracy: 0.5414 - loss: 1.4703 - val_accuracy: 0.4823 - val_loss: 1.7838
# Epoch 23/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 543ms/step - accuracy: 0.5676 - loss: 1.4328 - val_accuracy: 0.4867 - val_loss: 1.7723
# Epoch 24/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 611ms/step - accuracy: 0.5518 - loss: 1.3734 - val_accuracy: 0.4867 - val_loss: 1.7560
# Epoch 25/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 725ms/step - accuracy: 0.5695 - loss: 1.3886 - val_accuracy: 0.4867 - val_loss: 1.7435
# Epoch 26/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 672ms/step - accuracy: 0.5841 - loss: 1.3660 - val_accuracy: 0.4823 - val_loss: 1.7309
# Epoch 27/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 19s 657ms/step - accuracy: 0.6011 - loss: 1.3115 - val_accuracy: 0.4867 - val_loss: 1.7206
# Epoch 28/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 540ms/step - accuracy: 0.6209 - loss: 1.2231 - val_accuracy: 0.4956 - val_loss: 1.7123
# Epoch 29/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 619ms/step - accuracy: 0.6502 - loss: 1.1967 - val_accuracy: 0.5000 - val_loss: 1.6991
# Epoch 30/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 533ms/step - accuracy: 0.6448 - loss: 1.1763 - val_accuracy: 0.4912 - val_loss: 1.6900

# %%
from tensorflow.keras.preprocessing import image

image_path = "test13.jpg"   # <-- change if needed

# Load image
img = image.load_img(image_path, target_size=(img_size, img_size))

# Convert to array
img_array = image.img_to_array(img)

# Add batch dimension
img_array = np.expand_dims(img_array, axis=0)

# IMPORTANT: Apply same preprocessing
img_array = tf.keras.applications.efficientnet.preprocess_input(img_array)

# Predict
predictions = model.predict(img_array)

# Get predicted class
predicted_class_index = np.argmax(predictions)
confidence = np.max(predictions)

print("Predicted Class:", class_names[predicted_class_index])
print("Confidence:", round(float(confidence)*100, 2), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Predicted Class: Lyme Disease
# Confidence: 77.77 %

# %%
# base_model.trainable = True

# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
#     loss='sparse_categorical_crossentropy',
#     metrics=['accuracy']
# )

# history_fine = model.fit(
#     train_ds,
#     validation_data=val_ds,
#     epochs=5
# )

base_model.trainable = True

for layer in base_model.layers[:-15]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-6),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_fine = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=5
)
# Out:
# Epoch 1/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 45s 793ms/step - accuracy: 0.3699 - loss: 2.0232 - val_accuracy: 0.4115 - val_loss: 1.8976
# Epoch 2/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 734ms/step - accuracy: 0.3975 - loss: 1.9667 - val_accuracy: 0.4115 - val_loss: 1.9298
# Epoch 3/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 706ms/step - accuracy: 0.3903 - loss: 2.0102 - val_accuracy: 0.4071 - val_loss: 1.9555
# Epoch 4/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 699ms/step - accuracy: 0.3899 - loss: 2.0446 - val_accuracy: 0.3938 - val_loss: 1.9739
# Epoch 5/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 735ms/step - accuracy: 0.4408 - loss: 1.9662 - val_accuracy: 0.3982 - val_loss: 1.9871

# %%
epochs_range = range(30)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image_path = "test16.jpg"   # <-- change if needed

# Load image
img = image.load_img(image_path, target_size=(img_size, img_size))

# Convert to array
img_array = image.img_to_array(img)

# Add batch dimension
img_array = np.expand_dims(img_array, axis=0)

# IMPORTANT: Apply same preprocessing
img_array = tf.keras.applications.efficientnet.preprocess_input(img_array)

# Predict
predictions = model.predict(img_array)

# Get predicted class
predicted_class_index = np.argmax(predictions)
confidence = np.max(predictions)

print("Predicted Class:", class_names[predicted_class_index])
print("Confidence:", round(float(confidence)*100, 2), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted Class: Measles
# Confidence: 22.18 %

# %%
from sklearn.metrics import classification_report
import numpy as np

y_true = []
y_pred = []

for images, labels in val_ds:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 846ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 827ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 807ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
#                     precision    recall  f1-score   support
#
#               Acne       0.36      0.36      0.36        11
#  Actinic Keratosis       0.17      0.07      0.10        14
#      Chromhidrosis       0.15      0.22      0.18         9
# Eruptive Xanthomas       0.33      0.25      0.29         8
#         Erythrasma       0.33      0.50      0.40         4
#           Impetigo       0.17      0.14      0.15         7
#  Keratosis Pilaris       0.55      0.40      0.46        15
#            Leprosy       0.27      0.38      0.32         8
#              Lupus       0.43      0.27      0.33        11
#       Lyme Disease       0.45      0.42      0.43        12
#            Measles       0.73      0.62      0.67        13
#           Melanoma       0.67      0.86      0.75        14
#            Melasma       0.89      0.80      0.84        10
#           Otophyma       0.67      0.33      0.44         6
#           RingWorm       0.29      0.71      0.42         7
#           Scabies2       0.00      0.00      0.00         3
#           Shingles       0.40      0.31      0.35        13
#      Solar Lentigo       0.57      0.50      0.53         8
#     dermatofibroma       0.67      0.57      0.62         7
#             eczema       0.22      0.45      0.29        11
#              hives       0.27      0.27      0.27        15
#          psoriasis       0.33      0.33      0.33         6
#            rosacea       0.40      0.25      0.31         8
#            scabies       0.20      0.17      0.18         6
#
#           accuracy                           0.40       226
#          macro avg       0.40      0.38      0.38       226
#       weighted avg       0.42      0.40      0.40       226

# %%
model.save('Image_classify_v3.keras')
